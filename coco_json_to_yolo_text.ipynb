# %%
import json
import os
import shutil

# Путь к корневой папке
root_dir = "dataset_fire_smoke"

# Папка для YOLO данных
yolo_dir = os.path.join(root_dir, "yolo")
data_dir = os.path.join(yolo_dir, "data")

# Список папок для обработки
folders = {"474_fire_val": "val", "475_fire_train": "train"}

# Словарь для преобразования названий классов в ID
class_map = {"fire": 0, "smoke": 1}

def convert_coco_to_yolo(json_path, source_images_dir, target_images_dir, target_labels_dir):
    # Создаём папки для изображений и аннотаций
    os.makedirs(target_images_dir, exist_ok=True)
    os.makedirs(target_labels_dir, exist_ok=True)

    # Читаем JSON файл
    with open(json_path, 'r') as f:
        coco_data = json.load(f)

    # Создаём словарь изображений (id -> filename, width, height)
    images = {img["id"]: {"file_name": img["file_name"], "width": img["width"], "height": img["height"]}
              for img in coco_data["images"]}

    # Создаём словарь аннотаций по image_id
    annotations_by_image = {}
    for ann in coco_data["annotations"]:
        image_id = ann["image_id"]
        if image_id not in annotations_by_image:
            annotations_by_image[image_id] = []
        annotations_by_image[image_id].append(ann)

    # Обрабатываем каждое изображение
    for image_id, img_info in images.items():
        # Извлекаем только имя файла
        image_filename = os.path.basename(img_info["file_name"])
        source_image_path = os.path.join(source_images_dir, image_filename)
        target_image_path = os.path.join(target_images_dir, image_filename)
        
        if not os.path.exists(source_image_path):
            print(f"Изображение {source_image_path} не найдено, пропускаем.")
            continue

        # Копируем изображение в новую папку
        shutil.copy2(source_image_path, target_image_path)

        # Имя файла аннотации
        txt_filename = os.path.splitext(image_filename)[0] + ".txt"
        txt_path = os.path.join(target_labels_dir, txt_filename)

        # Проверяем, есть ли аннотации для этого изображения
        if image_id not in annotations_by_image:
            print(f"Нет аннотаций для {image_filename}, пропускаем.")
            continue

        # Открываем файл для записи
        with open(txt_path, 'w') as txt_file:
            for ann in annotations_by_image[image_id]:
                # Извлекаем bounding box и категорию
                bbox = ann["bbox"]  # [x_min, y_min, width, height]
                category_id = ann["category_id"]
                
                # Находим имя класса по category_id
                class_name = next(cat["name"] for cat in coco_data["categories"] if cat["id"] == category_id)
                class_id = class_map.get(class_name)
                if class_id is None:
                    print(f"Неизвестный класс: {class_name}")
                    continue

                # Преобразуем в YOLO формат
                img_width = img_info["width"]
                img_height = img_info["height"]
                
                x_min, y_min, width, height = bbox
                x_center = (x_min + width / 2) / img_width
                y_center = (y_min + height / 2) / img_height
                norm_width = width / img_width
                norm_height = height / img_height

                # Записываем в файл
                txt_file.write(f"{class_id} {x_center} {y_center} {norm_width} {norm_height}\n")

        print(f"Созданы аннотации для {image_filename} в {txt_path}")

# Создание структуры папок и обработка данных
for folder, split in folders.items():
    json_path = os.path.join(root_dir, folder, "annotations", "instances_default.json")
    source_images_dir = os.path.join(root_dir, folder, "images", "val" if folder == "474_fire_val" else "train")
    target_images_dir = os.path.join(data_dir, split, "images")
    target_labels_dir = os.path.join(data_dir, split, "labels")

    if not os.path.exists(json_path):
        print(f"Файл {json_path} не найден!")
        continue

    print(f"Обработка {folder} -> {split}...")
    convert_coco_to_yolo(json_path, source_images_dir, target_images_dir, target_labels_dir)

# Создание data.yaml
data_yaml_path = os.path.join(yolo_dir, "data.yaml")
with open(data_yaml_path, 'w') as f:
    f.write(f"""\
train: {os.path.join(data_dir, "train", "images")}
val: {os.path.join(data_dir, "val", "images")}
nc: 2
names: ['fire', 'smoke']
""")

print(f"Создан файл {data_yaml_path}")
print("Преобразование завершено!")
# Out:
# Обработка 474_fire_val -> val...
# Созданы аннотации для 000016.jpg в dataset_fire_smoke\yolo\data\val\labels\000016.txt
# Созданы аннотации для 000019.jpg в dataset_fire_smoke\yolo\data\val\labels\000019.txt
# Созданы аннотации для 000024.jpg в dataset_fire_smoke\yolo\data\val\labels\000024.txt
# Созданы аннотации для 000027.jpg в dataset_fire_smoke\yolo\data\val\labels\000027.txt
# Созданы аннотации для 000028.jpg в dataset_fire_smoke\yolo\data\val\labels\000028.txt
# Созданы аннотации для 000029.jpg в dataset_fire_smoke\yolo\data\val\labels\000029.txt
# Созданы аннотации для 000036.jpg в dataset_fire_smoke\yolo\data\val\labels\000036.txt
# Созданы аннотации для 000046.jpg в dataset_fire_smoke\yolo\data\val\labels\000046.txt
# Созданы аннотации для 000059.jpg в dataset_fire_smoke\yolo\data\val\labels\000059.txt
# Созданы аннотации для 000063.jpg в dataset_fire_smoke\yolo\data\val\labels\000063.txt
# Неизвестный класс: person
# Созданы аннотации для 000070.jpg в dataset_fire_smoke\yolo\data\val\labels\000070.txt
# Созданы аннотации для 000076.jpg в dataset_fire_smoke\yolo\data\val\labels\000076.txt
# Неизвестный класс: person
# Неизвестный класс: person
# Созданы аннотации для 000094.jpg в dataset_fire_smoke\yolo\data\val\labels\000094.txt
# Неизвестный класс: person
# Неизвестный класс: person
# Созданы аннотации для 000105.jpg в dataset_fire_smoke\yolo\data\val\labels\000105.txt
# Неизвестный класс: person
# Созданы аннотации для 000110.jpg в dataset_fire_smoke\yolo\data\val\labels\000110.txt
# Созданы аннотации для 000117.jpg в dataset_fire_smoke\yolo\data\val\labels\000117.txt
# Созданы аннотации для 000118.jpg в dataset_fire_smoke\yolo\data\val\labels\000118.txt
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Созданы аннотации для 000123.jpg в dataset_fire_smoke\yolo\data\val\labels\000123.txt
# Неизвестный класс: person
# Созданы аннотации для 000129.jpg в dataset_fire_smoke\yolo\data\val\labels\000129.txt
# Созданы аннотации для 000139.jpg в dataset_fire_smoke\yolo\data\val\labels\000139.txt
# Созданы аннотации для 000140.jpg в dataset_fire_smoke\yolo\data\val\labels\000140.txt
# Созданы аннотации для 000150.jpg в dataset_fire_smoke\yolo\data\val\labels\000150.txt
# Созданы аннотации для 000151.jpg в dataset_fire_smoke\yolo\data\val\labels\000151.txt
# Созданы аннотации для 000153.jpg в dataset_fire_smoke\yolo\data\val\labels\000153.txt
# Созданы аннотации для 000156.jpg в dataset_fire_smoke\yolo\data\val\labels\000156.txt
# Созданы аннотации для 000166.jpg в dataset_fire_smoke\yolo\data\val\labels\000166.txt
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Созданы аннотации для 000187.jpg в dataset_fire_smoke\yolo\data\val\labels\000187.txt
# Неизвестный класс: person
# Неизвестный класс: bicycle
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Созданы аннотации для 000213.jpg в dataset_fire_smoke\yolo\data\val\labels\000213.txt
# Неизвестный класс: person
# Созданы аннотации для 000219.jpg в dataset_fire_smoke\yolo\data\val\labels\000219.txt
# Созданы аннотации для 000220.jpg в dataset_fire_smoke\yolo\data\val\labels\000220.txt
# Неизвестный класс: person
# Неизвестный класс: person
# Созданы аннотации для 000228.jpg в dataset_fire_smoke\yolo\data\val\labels\000228.txt
# Созданы аннотации для 000231.jpg в dataset_fire_smoke\yolo\data\val\labels\000231.txt
# Созданы аннотации для 000238.jpg в dataset_fire_smoke\yolo\data\val\labels\000238.txt
# Созданы аннотации для 000249.jpg в dataset_fire_smoke\yolo\data\val\labels\000249.txt
# Созданы аннотации для 000252.jpg в dataset_fire_smoke\yolo\data\val\labels\000252.txt
# Неизвестный класс: person
# Неизвестный класс: person
# Созданы аннотации для 000262.jpg в dataset_fire_smoke\yolo\data\val\labels\000262.txt
# Неизвестный класс: person
# Созданы аннотации для 000270.jpg в dataset_fire_smoke\yolo\data\val\labels\000270.txt
# Созданы аннотации для 000315.jpg в dataset_fire_smoke\yolo\data\val\labels\000315.txt
# Созданы аннотации для 000324.jpg в dataset_fire_smoke\yolo\data\val\labels\000324.txt
# Созданы аннотации для 000325.jpg в dataset_fire_smoke\yolo\data\val\labels\000325.txt
# Созданы аннотации для 000332.jpg в dataset_fire_smoke\yolo\data\val\labels\000332.txt
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Созданы аннотации для 000336.jpg в dataset_fire_smoke\yolo\data\val\labels\000336.txt
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Созданы аннотации для 000346.jpg в dataset_fire_smoke\yolo\data\val\labels\000346.txt
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Созданы аннотации для 000356.jpg в dataset_fire_smoke\yolo\data\val\labels\000356.txt
# Неизвестный класс: person
# Неизвестный класс: person
# Созданы аннотации для 000362.jpg в dataset_fire_smoke\yolo\data\val\labels\000362.txt
# Созданы аннотации для 000365.jpg в dataset_fire_smoke\yolo\data\val\labels\000365.txt
# Созданы аннотации для 000390.jpg в dataset_fire_smoke\yolo\data\val\labels\000390.txt
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Созданы аннотации для 000398.jpg в dataset_fire_smoke\yolo\data\val\labels\000398.txt
# Созданы аннотации для 000401.jpg в dataset_fire_smoke\yolo\data\val\labels\000401.txt
# Созданы аннотации для 000416.jpg в dataset_fire_smoke\yolo\data\val\labels\000416.txt
# Созданы аннотации для 000420.jpg в dataset_fire_smoke\yolo\data\val\labels\000420.txt
# Созданы аннотации для 000435.jpg в dataset_fire_smoke\yolo\data\val\labels\000435.txt
# Созданы аннотации для 000438.jpg в dataset_fire_smoke\yolo\data\val\labels\000438.txt
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Созданы аннотации для 000451.jpg в dataset_fire_smoke\yolo\data\val\labels\000451.txt
# Созданы аннотации для 000452.jpg в dataset_fire_smoke\yolo\data\val\labels\000452.txt
# Созданы аннотации для 000462.jpg в dataset_fire_smoke\yolo\data\val\labels\000462.txt
# Созданы аннотации для 000467.jpg в dataset_fire_smoke\yolo\data\val\labels\000467.txt
# Созданы аннотации для 000470.jpg в dataset_fire_smoke\yolo\data\val\labels\000470.txt
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Созданы аннотации для 000478.jpg в dataset_fire_smoke\yolo\data\val\labels\000478.txt
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Созданы аннотации для 000494.jpg в dataset_fire_smoke\yolo\data\val\labels\000494.txt
# Созданы аннотации для 000499.jpg в dataset_fire_smoke\yolo\data\val\labels\000499.txt
# Созданы аннотации для 000501.jpg в dataset_fire_smoke\yolo\data\val\labels\000501.txt
# Созданы аннотации для 000515.jpg в dataset_fire_smoke\yolo\data\val\labels\000515.txt
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Созданы аннотации для 000522.jpg в dataset_fire_smoke\yolo\data\val\labels\000522.txt
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Созданы аннотации для 000538.jpg в dataset_fire_smoke\yolo\data\val\labels\000538.txt
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Созданы аннотации для 000553.jpg в dataset_fire_smoke\yolo\data\val\labels\000553.txt
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Созданы аннотации для 000574.jpg в dataset_fire_smoke\yolo\data\val\labels\000574.txt
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Созданы аннотации для 000575.jpg в dataset_fire_smoke\yolo\data\val\labels\000575.txt
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Созданы аннотации для 000580.jpg в dataset_fire_smoke\yolo\data\val\labels\000580.txt
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Созданы аннотации для 000597.jpg в dataset_fire_smoke\yolo\data\val\labels\000597.txt
# Неизвестный класс: person
# Неизвестный класс: person
# Созданы аннотации для 000611.jpg в dataset_fire_smoke\yolo\data\val\labels\000611.txt
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Созданы аннотации для 000617.jpg в dataset_fire_smoke\yolo\data\val\labels\000617.txt
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Созданы аннотации для 000621.jpg в dataset_fire_smoke\yolo\data\val\labels\000621.txt
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Созданы аннотации для 000626.jpg в dataset_fire_smoke\yolo\data\val\labels\000626.txt
# Созданы аннотации для 000631.jpg в dataset_fire_smoke\yolo\data\val\labels\000631.txt
# Созданы аннотации для 000659.jpg в dataset_fire_smoke\yolo\data\val\labels\000659.txt
# Неизвестный класс: person
# Созданы аннотации для 000688.jpg в dataset_fire_smoke\yolo\data\val\labels\000688.txt
# Созданы аннотации для 000689.jpg в dataset_fire_smoke\yolo\data\val\labels\000689.txt
# Созданы аннотации для 000690.jpg в dataset_fire_smoke\yolo\data\val\labels\000690.txt
# Созданы аннотации для 000708.jpg в dataset_fire_smoke\yolo\data\val\labels\000708.txt
# Созданы аннотации для 000710.jpg в dataset_fire_smoke\yolo\data\val\labels\000710.txt
# Созданы аннотации для 000715.jpg в dataset_fire_smoke\yolo\data\val\labels\000715.txt
# Созданы аннотации для 000720.jpg в dataset_fire_smoke\yolo\data\val\labels\000720.txt
# Неизвестный класс: person
# Созданы аннотации для 000734.jpg в dataset_fire_smoke\yolo\data\val\labels\000734.txt
# Созданы аннотации для 000741.jpg в dataset_fire_smoke\yolo\data\val\labels\000741.txt
# Созданы аннотации для 000912.jpg в dataset_fire_smoke\yolo\data\val\labels\000912.txt
# Неизвестный класс: person
# Неизвестный класс: person
# Созданы аннотации для 000957.jpg в dataset_fire_smoke\yolo\data\val\labels\000957.txt
# Созданы аннотации для 000986.jpg в dataset_fire_smoke\yolo\data\val\labels\000986.txt
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Созданы аннотации для 001080.jpg в dataset_fire_smoke\yolo\data\val\labels\001080.txt
# Созданы аннотации для 001111.jpg в dataset_fire_smoke\yolo\data\val\labels\001111.txt
# Созданы аннотации для 001113.jpg в dataset_fire_smoke\yolo\data\val\labels\001113.txt
# Созданы аннотации для 001124.jpg в dataset_fire_smoke\yolo\data\val\labels\001124.txt
# Созданы аннотации для 001126.jpg в dataset_fire_smoke\yolo\data\val\labels\001126.txt
# Созданы аннотации для 001134.jpg в dataset_fire_smoke\yolo\data\val\labels\001134.txt
# Созданы аннотации для 001156.jpg в dataset_fire_smoke\yolo\data\val\labels\001156.txt
# Созданы аннотации для 001162.jpg в dataset_fire_smoke\yolo\data\val\labels\001162.txt
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: motorcycle
# Неизвестный класс: person
# Неизвестный класс: person
# Созданы аннотации для 001247.jpg в dataset_fire_smoke\yolo\data\val\labels\001247.txt
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Созданы аннотации для 001383.jpg в dataset_fire_smoke\yolo\data\val\labels\001383.txt
# Созданы аннотации для 001397.jpg в dataset_fire_smoke\yolo\data\val\labels\001397.txt
# Неизвестный класс: person
# Созданы аннотации для 001404.jpg в dataset_fire_smoke\yolo\data\val\labels\001404.txt
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Созданы аннотации для 001418.jpg в dataset_fire_smoke\yolo\data\val\labels\001418.txt
# Неизвестный класс: person
# Неизвестный класс: person
# Созданы аннотации для 001445.jpg в dataset_fire_smoke\yolo\data\val\labels\001445.txt
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Созданы аннотации для 001454.jpg в dataset_fire_smoke\yolo\data\val\labels\001454.txt
# Созданы аннотации для 001473.jpg в dataset_fire_smoke\yolo\data\val\labels\001473.txt
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Созданы аннотации для 001476.jpg в dataset_fire_smoke\yolo\data\val\labels\001476.txt
# Созданы аннотации для 001512.jpg в dataset_fire_smoke\yolo\data\val\labels\001512.txt
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Созданы аннотации для 001675.jpg в dataset_fire_smoke\yolo\data\val\labels\001675.txt
# Созданы аннотации для 001715.jpg в dataset_fire_smoke\yolo\data\val\labels\001715.txt
# Созданы аннотации для 001820.jpg в dataset_fire_smoke\yolo\data\val\labels\001820.txt
# Созданы аннотации для 001930.jpg в dataset_fire_smoke\yolo\data\val\labels\001930.txt
# Созданы аннотации для 001944.jpg в dataset_fire_smoke\yolo\data\val\labels\001944.txt
# Созданы аннотации для 001963.jpg в dataset_fire_smoke\yolo\data\val\labels\001963.txt
# Неизвестный класс: person
# Неизвестный класс: person
# Созданы аннотации для 001977.jpg в dataset_fire_smoke\yolo\data\val\labels\001977.txt
# Созданы аннотации для 001989.jpg в dataset_fire_smoke\yolo\data\val\labels\001989.txt
# Неизвестный класс: person
# Неизвестный класс: person
# Созданы аннотации для 002002.jpg в dataset_fire_smoke\yolo\data\val\labels\002002.txt
# Созданы аннотации для 002005.jpg в dataset_fire_smoke\yolo\data\val\labels\002005.txt
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Созданы аннотации для 002025.jpg в dataset_fire_smoke\yolo\data\val\labels\002025.txt
# Созданы аннотации для 002028.jpg в dataset_fire_smoke\yolo\data\val\labels\002028.txt
# Созданы аннотации для 002038.jpg в dataset_fire_smoke\yolo\data\val\labels\002038.txt
# Созданы аннотации для 002060.jpg в dataset_fire_smoke\yolo\data\val\labels\002060.txt
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Созданы аннотации для 002080.jpg в dataset_fire_smoke\yolo\data\val\labels\002080.txt
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Созданы аннотации для 002081.jpg в dataset_fire_smoke\yolo\data\val\labels\002081.txt
# Созданы аннотации для 002088.jpg в dataset_fire_smoke\yolo\data\val\labels\002088.txt
# Созданы аннотации для 002123.jpg в dataset_fire_smoke\yolo\data\val\labels\002123.txt
# Созданы аннотации для 002129.jpg в dataset_fire_smoke\yolo\data\val\labels\002129.txt
# Созданы аннотации для 002139.jpg в dataset_fire_smoke\yolo\data\val\labels\002139.txt
# Созданы аннотации для 002169.jpg в dataset_fire_smoke\yolo\data\val\labels\002169.txt
# Созданы аннотации для 0aa20ec0-3ff3-41d4-a3a7-65c03c383851.jpg в dataset_fire_smoke\yolo\data\val\labels\0aa20ec0-3ff3-41d4-a3a7-65c03c383851.txt
# Созданы аннотации для 12826b80-9a31-49fb-8c57-514799126d77.jpg в dataset_fire_smoke\yolo\data\val\labels\12826b80-9a31-49fb-8c57-514799126d77.txt
# Созданы аннотации для 12d657fc-66f3-413f-956d-e37f52bb4c38.jpg в dataset_fire_smoke\yolo\data\val\labels\12d657fc-66f3-413f-956d-e37f52bb4c38.txt
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Созданы аннотации для 150389db-ed76-48f2-807b-24f0abf65bca.jpg в dataset_fire_smoke\yolo\data\val\labels\150389db-ed76-48f2-807b-24f0abf65bca.txt
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: bicycle
# Неизвестный класс: person
# Неизвестный класс: person
# Созданы аннотации для 16a3592f-8d7d-40c9-9e2b-2c0ab5b0e053.jpg в dataset_fire_smoke\yolo\data\val\labels\16a3592f-8d7d-40c9-9e2b-2c0ab5b0e053.txt
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Созданы аннотации для 1_23.jpg в dataset_fire_smoke\yolo\data\val\labels\1_23.txt
# Созданы аннотации для 1_85.jpg в dataset_fire_smoke\yolo\data\val\labels\1_85.txt
# Созданы аннотации для 1b798c3b-ad81-4c34-ae18-31240a6e894e.jpg в dataset_fire_smoke\yolo\data\val\labels\1b798c3b-ad81-4c34-ae18-31240a6e894e.txt
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Созданы аннотации для 1da54983-4378-4161-a79b-30d9cc9e03f1.jpg в dataset_fire_smoke\yolo\data\val\labels\1da54983-4378-4161-a79b-30d9cc9e03f1.txt
# Созданы аннотации для 20200713171327.jpg в dataset_fire_smoke\yolo\data\val\labels\20200713171327.txt
# Созданы аннотации для 20200713172614.jpg в dataset_fire_smoke\yolo\data\val\labels\20200713172614.txt
# Созданы аннотации для 235e6cfc-3fd9-4a4f-87dd-ab92ace33cb5.jpg в dataset_fire_smoke\yolo\data\val\labels\235e6cfc-3fd9-4a4f-87dd-ab92ace33cb5.txt
# Созданы аннотации для 2ed67d9e-b71d-4bab-9908-29c60de21aa6.jpg в dataset_fire_smoke\yolo\data\val\labels\2ed67d9e-b71d-4bab-9908-29c60de21aa6.txt
# Созданы аннотации для 2ndfloorFULLYINVOLVEDHelmetCam1713.jpg в dataset_fire_smoke\yolo\data\val\labels\2ndfloorFULLYINVOLVEDHelmetCam1713.txt
# Неизвестный класс: person
# Созданы аннотации для 369e5f7c-528a-4278-82d7-486d3bcdec36.jpg в dataset_fire_smoke\yolo\data\val\labels\369e5f7c-528a-4278-82d7-486d3bcdec36.txt
# Созданы аннотации для 407723be-ccfe-4ca3-918f-4d56c0f749e3.jpg в dataset_fire_smoke\yolo\data\val\labels\407723be-ccfe-4ca3-918f-4d56c0f749e3.txt
# Неизвестный класс: person
# Неизвестный класс: person
# Созданы аннотации для 45a4c46c-727a-4658-a819-9571de3c3275.jpg в dataset_fire_smoke\yolo\data\val\labels\45a4c46c-727a-4658-a819-9571de3c3275.txt
# Созданы аннотации для 471dc985-6597-42e4-95d8-7530807e314e.jpg в dataset_fire_smoke\yolo\data\val\labels\471dc985-6597-42e4-95d8-7530807e314e.txt
# Неизвестный класс: person
# Созданы аннотации для 4d0cea58-76d1-4e34-ab1c-32bcbf324bdb.jpg в dataset_fire_smoke\yolo\data\val\labels\4d0cea58-76d1-4e34-ab1c-32bcbf324bdb.txt
# Неизвестный класс: person
# Созданы аннотации для 4faaf967-a526-4422-8126-c0aa630a9dee.jpg в dataset_fire_smoke\yolo\data\val\labels\4faaf967-a526-4422-8126-c0aa630a9dee.txt
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Созданы аннотации для 56b81f4c-114f-471f-a3ca-89c0ff81c06a.jpg в dataset_fire_smoke\yolo\data\val\labels\56b81f4c-114f-471f-a3ca-89c0ff81c06a.txt
# Неизвестный класс: motorcycle
# Неизвестный класс: person
# Созданы аннотации для 58a1ebd8-c42e-4cd3-bfe8-6bebac22a983.jpg в dataset_fire_smoke\yolo\data\val\labels\58a1ebd8-c42e-4cd3-bfe8-6bebac22a983.txt
# Созданы аннотации для 58bd57ad-da92-4676-b8ce-ada0eea0327c.jpg в dataset_fire_smoke\yolo\data\val\labels\58bd57ad-da92-4676-b8ce-ada0eea0327c.txt
# Неизвестный класс: person
# Созданы аннотации для 607fc186-3e5b-45d4-b463-3209c176a735.jpg в dataset_fire_smoke\yolo\data\val\labels\607fc186-3e5b-45d4-b463-3209c176a735.txt
# Созданы аннотации для 61343b86-1237-419e-9ad2-2606fa0cf15a.jpg в dataset_fire_smoke\yolo\data\val\labels\61343b86-1237-419e-9ad2-2606fa0cf15a.txt
# Созданы аннотации для 63daf86d-25d4-41cc-9c81-5a02d702a0a9.jpg в dataset_fire_smoke\yolo\data\val\labels\63daf86d-25d4-41cc-9c81-5a02d702a0a9.txt
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Созданы аннотации для 647a1ee5-ab79-442b-a1a4-1e1f82ea89a1.jpg в dataset_fire_smoke\yolo\data\val\labels\647a1ee5-ab79-442b-a1a4-1e1f82ea89a1.txt
# Созданы аннотации для 6c1e4ebe-16e0-4a7a-bb9d-8fcaeb084317.jpg в dataset_fire_smoke\yolo\data\val\labels\6c1e4ebe-16e0-4a7a-bb9d-8fcaeb084317.txt
# Неизвестный класс: person
# Созданы аннотации для 6f1f403c-1a5c-48e7-aae8-357fbd4afad5.jpg в dataset_fire_smoke\yolo\data\val\labels\6f1f403c-1a5c-48e7-aae8-357fbd4afad5.txt
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Созданы аннотации для 73bd7d61-a230-4bed-947e-7b5026310de2.jpg в dataset_fire_smoke\yolo\data\val\labels\73bd7d61-a230-4bed-947e-7b5026310de2.txt
# Созданы аннотации для 74d476cb-1501-4f6a-802f-6bd0b41a65ae.jpg в dataset_fire_smoke\yolo\data\val\labels\74d476cb-1501-4f6a-802f-6bd0b41a65ae.txt
# Созданы аннотации для 7e8692fa-61bf-484d-8b46-2084f74f8e22.jpg в dataset_fire_smoke\yolo\data\val\labels\7e8692fa-61bf-484d-8b46-2084f74f8e22.txt
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Созданы аннотации для 7f0de8d7-9834-4cce-a415-3a76dcce987d.jpg в dataset_fire_smoke\yolo\data\val\labels\7f0de8d7-9834-4cce-a415-3a76dcce987d.txt
# Созданы аннотации для 8de85b11-d20f-4699-8154-d1689467954e.jpg в dataset_fire_smoke\yolo\data\val\labels\8de85b11-d20f-4699-8154-d1689467954e.txt
# Неизвестный класс: person
# Созданы аннотации для 92d8d882-a12c-406c-91f9-fd95991f6a33.jpg в dataset_fire_smoke\yolo\data\val\labels\92d8d882-a12c-406c-91f9-fd95991f6a33.txt
# Неизвестный класс: person
# Созданы аннотации для 95d1ea1b-bd89-4069-b3c6-1401b8c875e1.jpg в dataset_fire_smoke\yolo\data\val\labels\95d1ea1b-bd89-4069-b3c6-1401b8c875e1.txt
# Созданы аннотации для 9ca397f2-8ae1-46fe-991d-748a84a18761.jpg в dataset_fire_smoke\yolo\data\val\labels\9ca397f2-8ae1-46fe-991d-748a84a18761.txt
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Созданы аннотации для 9d93fc99-db7e-406b-a6df-44027d9158c1.jpg в dataset_fire_smoke\yolo\data\val\labels\9d93fc99-db7e-406b-a6df-44027d9158c1.txt
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Созданы аннотации для CarThree1.jpg в dataset_fire_smoke\yolo\data\val\labels\CarThree1.txt
# Созданы аннотации для acfe72f7-2e13-45dd-81d7-c1df72196cc6.jpg в dataset_fire_smoke\yolo\data\val\labels\acfe72f7-2e13-45dd-81d7-c1df72196cc6.txt
# Созданы аннотации для b80d8bdf-a93d-465e-b24e-17643ad7ac68.jpg в dataset_fire_smoke\yolo\data\val\labels\b80d8bdf-a93d-465e-b24e-17643ad7ac68.txt
# Созданы аннотации для b8855238-2743-4b09-8964-8dbb83050e20.jpg в dataset_fire_smoke\yolo\data\val\labels\b8855238-2743-4b09-8964-8dbb83050e20.txt
# Созданы аннотации для bfc2fc11-03e1-448b-9aa3-e6d19824d986.jpg в dataset_fire_smoke\yolo\data\val\labels\bfc2fc11-03e1-448b-9aa3-e6d19824d986.txt
# Неизвестный класс: person
# Созданы аннотации для case2_car411.jpg в dataset_fire_smoke\yolo\data\val\labels\case2_car411.txt
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Созданы аннотации для cc62d9cc-0df6-46da-8d1b-67b12e115351.jpg в dataset_fire_smoke\yolo\data\val\labels\cc62d9cc-0df6-46da-8d1b-67b12e115351.txt
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Созданы аннотации для df235e59-fd61-4906-906c-336d9b556c5a.jpg в dataset_fire_smoke\yolo\data\val\labels\df235e59-fd61-4906-906c-336d9b556c5a.txt
# Созданы аннотации для f510bac7-0aad-4b76-b9b2-82f1ebf5eb85.jpg в dataset_fire_smoke\yolo\data\val\labels\f510bac7-0aad-4b76-b9b2-82f1ebf5eb85.txt
# Созданы аннотации для fire100.jpg в dataset_fire_smoke\yolo\data\val\labels\fire100.txt
# Неизвестный класс: person
# Созданы аннотации для fire113.jpg в dataset_fire_smoke\yolo\data\val\labels\fire113.txt
# Созданы аннотации для hand_held_camera_wildfire70.jpg в dataset_fire_smoke\yolo\data\val\labels\hand_held_camera_wildfire70.txt
# Неизвестный класс: person
# Созданы аннотации для images (1006).jpg в dataset_fire_smoke\yolo\data\val\labels\images (1006).txt
# Неизвестный класс: person
# Неизвестный класс: person
# Созданы аннотации для images (1016).jpg в dataset_fire_smoke\yolo\data\val\labels\images (1016).txt
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Созданы аннотации для images (1039).jpg в dataset_fire_smoke\yolo\data\val\labels\images (1039).txt
# Созданы аннотации для images (173).jpg в dataset_fire_smoke\yolo\data\val\labels\images (173).txt
# Созданы аннотации для images (2487).jpg в dataset_fire_smoke\yolo\data\val\labels\images (2487).txt
# Созданы аннотации для images (2505).jpg в dataset_fire_smoke\yolo\data\val\labels\images (2505).txt
# Созданы аннотации для images (2508).jpg в dataset_fire_smoke\yolo\data\val\labels\images (2508).txt
# Созданы аннотации для images (2509).jpg в dataset_fire_smoke\yolo\data\val\labels\images (2509).txt
# Неизвестный класс: person
# Неизвестный класс: person
# Созданы аннотации для images (2520).jpg в dataset_fire_smoke\yolo\data\val\labels\images (2520).txt
# Созданы аннотации для images (2555).jpg в dataset_fire_smoke\yolo\data\val\labels\images (2555).txt
# Созданы аннотации для images (2563).jpg в dataset_fire_smoke\yolo\data\val\labels\images (2563).txt
# Неизвестный класс: person
# Созданы аннотации для images (2570).jpg в dataset_fire_smoke\yolo\data\val\labels\images (2570).txt
# Неизвестный класс: person
# Созданы аннотации для images (2572).jpg в dataset_fire_smoke\yolo\data\val\labels\images (2572).txt
# Созданы аннотации для images (2603).jpg в dataset_fire_smoke\yolo\data\val\labels\images (2603).txt
# Созданы аннотации для images (2609).jpg в dataset_fire_smoke\yolo\data\val\labels\images (2609).txt
# Созданы аннотации для images (2613).jpg в dataset_fire_smoke\yolo\data\val\labels\images (2613).txt
# Созданы аннотации для images (2648).jpg в dataset_fire_smoke\yolo\data\val\labels\images (2648).txt
# Неизвестный класс: person
# Неизвестный класс: person
# Созданы аннотации для images (2656).jpg в dataset_fire_smoke\yolo\data\val\labels\images (2656).txt
# Неизвестный класс: person
# Неизвестный класс: person
# Созданы аннотации для images (2719).jpg в dataset_fire_smoke\yolo\data\val\labels\images (2719).txt
# Созданы аннотации для images (2720).jpg в dataset_fire_smoke\yolo\data\val\labels\images (2720).txt
# Созданы аннотации для images (2740).jpg в dataset_fire_smoke\yolo\data\val\labels\images (2740).txt
# Созданы аннотации для images (2741).jpg в dataset_fire_smoke\yolo\data\val\labels\images (2741).txt
# Созданы аннотации для images (2744).jpg в dataset_fire_smoke\yolo\data\val\labels\images (2744).txt
# Созданы аннотации для images (2755).jpg в dataset_fire_smoke\yolo\data\val\labels\images (2755).txt
# Неизвестный класс: person
# Созданы аннотации для images (2802).jpg в dataset_fire_smoke\yolo\data\val\labels\images (2802).txt
# Созданы аннотации для images (2830).jpg в dataset_fire_smoke\yolo\data\val\labels\images (2830).txt
# Созданы аннотации для images (2892).jpg в dataset_fire_smoke\yolo\data\val\labels\images (2892).txt
# Созданы аннотации для images (2894).jpg в dataset_fire_smoke\yolo\data\val\labels\images (2894).txt
# Созданы аннотации для images (2895).jpg в dataset_fire_smoke\yolo\data\val\labels\images (2895).txt
# Созданы аннотации для images (2938).jpg в dataset_fire_smoke\yolo\data\val\labels\images (2938).txt
# Созданы аннотации для images (2965).jpg в dataset_fire_smoke\yolo\data\val\labels\images (2965).txt
# Неизвестный класс: person
# Созданы аннотации для images (3048).jpg в dataset_fire_smoke\yolo\data\val\labels\images (3048).txt
# Неизвестный класс: person
# Неизвестный класс: person
# Созданы аннотации для images (3063).jpg в dataset_fire_smoke\yolo\data\val\labels\images (3063).txt
# Созданы аннотации для images (3168).jpg в dataset_fire_smoke\yolo\data\val\labels\images (3168).txt
# Созданы аннотации для images (323).jpg в dataset_fire_smoke\yolo\data\val\labels\images (323).txt
# Неизвестный класс: person
# Неизвестный класс: person
# Созданы аннотации для images (341).jpg в dataset_fire_smoke\yolo\data\val\labels\images (341).txt
# Созданы аннотации для images (470).jpg в dataset_fire_smoke\yolo\data\val\labels\images (470).txt
# Созданы аннотации для images (474).jpg в dataset_fire_smoke\yolo\data\val\labels\images (474).txt
# Созданы аннотации для images (527).jpg в dataset_fire_smoke\yolo\data\val\labels\images (527).txt
# Неизвестный класс: person
# Неизвестный класс: person
# Созданы аннотации для images (529).jpg в dataset_fire_smoke\yolo\data\val\labels\images (529).txt
# Созданы аннотации для images (562).jpg в dataset_fire_smoke\yolo\data\val\labels\images (562).txt
# Созданы аннотации для images (602).jpg в dataset_fire_smoke\yolo\data\val\labels\images (602).txt
# Созданы аннотации для images (620).jpg в dataset_fire_smoke\yolo\data\val\labels\images (620).txt
# Неизвестный класс: person
# Созданы аннотации для images (645).jpg в dataset_fire_smoke\yolo\data\val\labels\images (645).txt
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Созданы аннотации для images (660).jpg в dataset_fire_smoke\yolo\data\val\labels\images (660).txt
# Созданы аннотации для images (695).jpg в dataset_fire_smoke\yolo\data\val\labels\images (695).txt
# Созданы аннотации для images (699).jpg в dataset_fire_smoke\yolo\data\val\labels\images (699).txt
# Созданы аннотации для images (701).jpg в dataset_fire_smoke\yolo\data\val\labels\images (701).txt
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Созданы аннотации для images (706).jpg в dataset_fire_smoke\yolo\data\val\labels\images (706).txt
# Созданы аннотации для images (716).jpg в dataset_fire_smoke\yolo\data\val\labels\images (716).txt
# Созданы аннотации для images (734).jpg в dataset_fire_smoke\yolo\data\val\labels\images (734).txt
# Созданы аннотации для images (841).jpg в dataset_fire_smoke\yolo\data\val\labels\images (841).txt
# Созданы аннотации для images (882).jpg в dataset_fire_smoke\yolo\data\val\labels\images (882).txt
# Созданы аннотации для images (905).jpg в dataset_fire_smoke\yolo\data\val\labels\images (905).txt
# Созданы аннотации для images (906).jpg в dataset_fire_smoke\yolo\data\val\labels\images (906).txt
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Созданы аннотации для images (908).jpg в dataset_fire_smoke\yolo\data\val\labels\images (908).txt
# Созданы аннотации для images (920).jpg в dataset_fire_smoke\yolo\data\val\labels\images (920).txt
# Созданы аннотации для images (955).jpg в dataset_fire_smoke\yolo\data\val\labels\images (955).txt
# Созданы аннотации для images (958).jpg в dataset_fire_smoke\yolo\data\val\labels\images (958).txt
# Созданы аннотации для images (989).jpg в dataset_fire_smoke\yolo\data\val\labels\images (989).txt
# Созданы аннотации для img(102).jpg в dataset_fire_smoke\yolo\data\val\labels\img(102).txt
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Созданы аннотации для img(105).jpg в dataset_fire_smoke\yolo\data\val\labels\img(105).txt
# Созданы аннотации для img(122).jpg в dataset_fire_smoke\yolo\data\val\labels\img(122).txt
# Созданы аннотации для img(127).jpg в dataset_fire_smoke\yolo\data\val\labels\img(127).txt
# Созданы аннотации для img(134).jpg в dataset_fire_smoke\yolo\data\val\labels\img(134).txt
# Неизвестный класс: person
# Созданы аннотации для img(139).jpg в dataset_fire_smoke\yolo\data\val\labels\img(139).txt
# Созданы аннотации для img(141).jpg в dataset_fire_smoke\yolo\data\val\labels\img(141).txt
# Созданы аннотации для img(143).jpg в dataset_fire_smoke\yolo\data\val\labels\img(143).txt
# Созданы аннотации для img(147).jpg в dataset_fire_smoke\yolo\data\val\labels\img(147).txt
# Созданы аннотации для img(26).jpg в dataset_fire_smoke\yolo\data\val\labels\img(26).txt
# Созданы аннотации для img(54).jpg в dataset_fire_smoke\yolo\data\val\labels\img(54).txt
# Созданы аннотации для img(56).jpg в dataset_fire_smoke\yolo\data\val\labels\img(56).txt
# Неизвестный класс: person
# Неизвестный класс: person
# Созданы аннотации для img(7).jpg в dataset_fire_smoke\yolo\data\val\labels\img(7).txt
# Созданы аннотации для img(74).jpg в dataset_fire_smoke\yolo\data\val\labels\img(74).txt
# Созданы аннотации для img(97).jpg в dataset_fire_smoke\yolo\data\val\labels\img(97).txt
# Созданы аннотации для img(98).jpg в dataset_fire_smoke\yolo\data\val\labels\img(98).txt
# Созданы аннотации для pic(110).jpg в dataset_fire_smoke\yolo\data\val\labels\pic(110).txt
# Созданы аннотации для pic(119).jpg в dataset_fire_smoke\yolo\data\val\labels\pic(119).txt
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Созданы аннотации для pic(147).jpg в dataset_fire_smoke\yolo\data\val\labels\pic(147).txt
# Неизвестный класс: person
# Неизвестный класс: person
# Созданы аннотации для pic(148).jpg в dataset_fire_smoke\yolo\data\val\labels\pic(148).txt
# Созданы аннотации для pic(157).jpg в dataset_fire_smoke\yolo\data\val\labels\pic(157).txt
# Созданы аннотации для pic(158).jpg в dataset_fire_smoke\yolo\data\val\labels\pic(158).txt
# Созданы аннотации для pic(175).jpg в dataset_fire_smoke\yolo\data\val\labels\pic(175).txt
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Созданы аннотации для pic(202).jpg в dataset_fire_smoke\yolo\data\val\labels\pic(202).txt
# Созданы аннотации для pic(205).jpg в dataset_fire_smoke\yolo\data\val\labels\pic(205).txt
# Неизвестный класс: person
# Неизвестный класс: person
# Созданы аннотации для pic(206).jpg в dataset_fire_smoke\yolo\data\val\labels\pic(206).txt
# Созданы аннотации для pic(208).jpg в dataset_fire_smoke\yolo\data\val\labels\pic(208).txt
# Неизвестный класс: person
# Неизвестный класс: person
# Созданы аннотации для pic(37).jpg в dataset_fire_smoke\yolo\data\val\labels\pic(37).txt
# Созданы аннотации для pic(48).jpg в dataset_fire_smoke\yolo\data\val\labels\pic(48).txt
# Созданы аннотации для pic(58).jpg в dataset_fire_smoke\yolo\data\val\labels\pic(58).txt
# Созданы аннотации для pic(74).jpg в dataset_fire_smoke\yolo\data\val\labels\pic(74).txt
# Созданы аннотации для pic(83).jpg в dataset_fire_smoke\yolo\data\val\labels\pic(83).txt
# Созданы аннотации для pic(87).jpg в dataset_fire_smoke\yolo\data\val\labels\pic(87).txt
# Неизвестный класс: person
# Неизвестный класс: person
# Созданы аннотации для pic(98).jpg в dataset_fire_smoke\yolo\data\val\labels\pic(98).txt
# Неизвестный класс: person
# Неизвестный класс: person
# Созданы аннотации для sm_000068.jpg в dataset_fire_smoke\yolo\data\val\labels\sm_000068.txt
# Неизвестный класс: person
# Неизвестный класс: person
# Созданы аннотации для sm_000070.jpg в dataset_fire_smoke\yolo\data\val\labels\sm_000070.txt
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Созданы аннотации для sm_000220.jpg в dataset_fire_smoke\yolo\data\val\labels\sm_000220.txt
# Созданы аннотации для sm_000337.jpg в dataset_fire_smoke\yolo\data\val\labels\sm_000337.txt
# Созданы аннотации для sm_000600.jpg в dataset_fire_smoke\yolo\data\val\labels\sm_000600.txt
# Созданы аннотации для sm_000907.jpg в dataset_fire_smoke\yolo\data\val\labels\sm_000907.txt
# Созданы аннотации для sm_000960.jpg в dataset_fire_smoke\yolo\data\val\labels\sm_000960.txt
# Созданы аннотации для sm_000999.jpg в dataset_fire_smoke\yolo\data\val\labels\sm_000999.txt
# Созданы аннотации для sm_001028.jpg в dataset_fire_smoke\yolo\data\val\labels\sm_001028.txt
# Созданы аннотации для sm_001031.jpg в dataset_fire_smoke\yolo\data\val\labels\sm_001031.txt
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Созданы аннотации для sm_001038.jpg в dataset_fire_smoke\yolo\data\val\labels\sm_001038.txt
# Неизвестный класс: person
# Созданы аннотации для sm_001039.jpg в dataset_fire_smoke\yolo\data\val\labels\sm_001039.txt
# Неизвестный класс: person
# Неизвестный класс: person
# Созданы аннотации для sm_001074.jpg в dataset_fire_smoke\yolo\data\val\labels\sm_001074.txt
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Созданы аннотации для sm_001093.jpg в dataset_fire_smoke\yolo\data\val\labels\sm_001093.txt
# Неизвестный класс: person
# Созданы аннотации для sm_001128.jpg в dataset_fire_smoke\yolo\data\val\labels\sm_001128.txt
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Созданы аннотации для sm_001140.jpg в dataset_fire_smoke\yolo\data\val\labels\sm_001140.txt
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Созданы аннотации для sm_001148.jpg в dataset_fire_smoke\yolo\data\val\labels\sm_001148.txt
# Созданы аннотации для sm_001205.jpg в dataset_fire_smoke\yolo\data\val\labels\sm_001205.txt
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Созданы аннотации для sm_001329.jpg в dataset_fire_smoke\yolo\data\val\labels\sm_001329.txt
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Созданы аннотации для sm_001357.jpg в dataset_fire_smoke\yolo\data\val\labels\sm_001357.txt
# Неизвестный класс: person
# Неизвестный класс: person
# Созданы аннотации для sm_001382.jpg в dataset_fire_smoke\yolo\data\val\labels\sm_001382.txt
# Неизвестный класс: person
# Неизвестный класс: person
# Созданы аннотации для sm_001386.jpg в dataset_fire_smoke\yolo\data\val\labels\sm_001386.txt
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Созданы аннотации для sm_001438.jpg в dataset_fire_smoke\yolo\data\val\labels\sm_001438.txt
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Созданы аннотации для sm_001456.jpg в dataset_fire_smoke\yolo\data\val\labels\sm_001456.txt
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: motorcycle
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: motorcycle
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Созданы аннотации для sm_001460.jpg в dataset_fire_smoke\yolo\data\val\labels\sm_001460.txt
# Созданы аннотации для sm_001470.jpg в dataset_fire_smoke\yolo\data\val\labels\sm_001470.txt
# Созданы аннотации для sm_001505.jpg в dataset_fire_smoke\yolo\data\val\labels\sm_001505.txt
# Созданы аннотации для sm_001536.jpg в dataset_fire_smoke\yolo\data\val\labels\sm_001536.txt
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Созданы аннотации для sm_001553.jpg в dataset_fire_smoke\yolo\data\val\labels\sm_001553.txt
# Неизвестный класс: person
# Созданы аннотации для sm_001554.jpg в dataset_fire_smoke\yolo\data\val\labels\sm_001554.txt
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Созданы аннотации для sm_001595.jpg в dataset_fire_smoke\yolo\data\val\labels\sm_001595.txt
# Неизвестный класс: person
# ...
# Созданы аннотации для sm_001803.jpg в dataset_fire_smoke\yolo\data\train\labels\sm_001803.txt
# Созданы аннотации для sm_001809.jpg в dataset_fire_smoke\yolo\data\train\labels\sm_001809.txt
# Неизвестный класс: person
# Созданы аннотации для sm_00182.jpg в dataset_fire_smoke\yolo\data\train\labels\sm_00182.txt
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Созданы аннотации для sm_00210.jpg в dataset_fire_smoke\yolo\data\train\labels\sm_00210.txt
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Созданы аннотации для sm_00219.jpg в dataset_fire_smoke\yolo\data\train\labels\sm_00219.txt
# Неизвестный класс: motorcycle
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: motorcycle
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: bicycle
# Неизвестный класс: motorcycle
# Неизвестный класс: person
# Неизвестный класс: motorcycle
# Неизвестный класс: person
# Неизвестный класс: bicycle
# Созданы аннотации для sm_00248.jpg в dataset_fire_smoke\yolo\data\train\labels\sm_00248.txt
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Созданы аннотации для sm_00283.jpg в dataset_fire_smoke\yolo\data\train\labels\sm_00283.txt
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: motorcycle
# Неизвестный класс: motorcycle
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: motorcycle
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Созданы аннотации для sm_00316.jpg в dataset_fire_smoke\yolo\data\train\labels\sm_00316.txt
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Созданы аннотации для sm_00333.jpg в dataset_fire_smoke\yolo\data\train\labels\sm_00333.txt
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Созданы аннотации для sm_00374.jpg в dataset_fire_smoke\yolo\data\train\labels\sm_00374.txt
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Созданы аннотации для sm_00387.jpg в dataset_fire_smoke\yolo\data\train\labels\sm_00387.txt
# Неизвестный класс: person
# Неизвестный класс: motorcycle
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Созданы аннотации для sm_00563.jpg в dataset_fire_smoke\yolo\data\train\labels\sm_00563.txt
# Созданы аннотации для sm_00571.jpg в dataset_fire_smoke\yolo\data\train\labels\sm_00571.txt
# Созданы аннотации для sm_00575.jpg в dataset_fire_smoke\yolo\data\train\labels\sm_00575.txt
# Неизвестный класс: motorcycle
# Неизвестный класс: motorcycle
# Неизвестный класс: motorcycle
# Созданы аннотации для sm_00666.jpg в dataset_fire_smoke\yolo\data\train\labels\sm_00666.txt
# Созданы аннотации для sm_00697.jpg в dataset_fire_smoke\yolo\data\train\labels\sm_00697.txt
# Созданы аннотации для sm_00717.jpg в dataset_fire_smoke\yolo\data\train\labels\sm_00717.txt
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: motorcycle
# Неизвестный класс: motorcycle
# Неизвестный класс: motorcycle
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: motorcycle
# Неизвестный класс: motorcycle
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: motorcycle
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: motorcycle
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: bicycle
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: motorcycle
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: motorcycle
# Неизвестный класс: motorcycle
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: motorcycle
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Созданы аннотации для sm_00755.jpg в dataset_fire_smoke\yolo\data\train\labels\sm_00755.txt
# Созданы аннотации для sm_00768.jpg в dataset_fire_smoke\yolo\data\train\labels\sm_00768.txt
# Созданы аннотации для sm_00770.jpg в dataset_fire_smoke\yolo\data\train\labels\sm_00770.txt
# Созданы аннотации для sm_00786.jpg в dataset_fire_smoke\yolo\data\train\labels\sm_00786.txt
# Созданы аннотации для sm_00789.jpg в dataset_fire_smoke\yolo\data\train\labels\sm_00789.txt
# Созданы аннотации для sm_00792.jpg в dataset_fire_smoke\yolo\data\train\labels\sm_00792.txt
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Созданы аннотации для sm_00809.jpg в dataset_fire_smoke\yolo\data\train\labels\sm_00809.txt
# Неизвестный класс: person
# Созданы аннотации для sm_00812.jpg в dataset_fire_smoke\yolo\data\train\labels\sm_00812.txt
# Созданы аннотации для sm_00819.jpg в dataset_fire_smoke\yolo\data\train\labels\sm_00819.txt
# Созданы аннотации для sm_00824.jpg в dataset_fire_smoke\yolo\data\train\labels\sm_00824.txt
# Неизвестный класс: person
# Неизвестный класс: motorcycle
# Неизвестный класс: bicycle
# Неизвестный класс: bicycle
# Неизвестный класс: person
# Неизвестный класс: motorcycle
# Неизвестный класс: person
# Неизвестный класс: person
# Созданы аннотации для sm_00825.jpg в dataset_fire_smoke\yolo\data\train\labels\sm_00825.txt
# Неизвестный класс: person
# Неизвестный класс: person
# Созданы аннотации для sm_00853.jpg в dataset_fire_smoke\yolo\data\train\labels\sm_00853.txt
# Созданы аннотации для sm_00879.jpg в dataset_fire_smoke\yolo\data\train\labels\sm_00879.txt
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Созданы аннотации для sm_00881.jpg в dataset_fire_smoke\yolo\data\train\labels\sm_00881.txt
# Созданы аннотации для sm_00885.jpg в dataset_fire_smoke\yolo\data\train\labels\sm_00885.txt
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Созданы аннотации для sm_00886.jpg в dataset_fire_smoke\yolo\data\train\labels\sm_00886.txt
# Неизвестный класс: motorcycle
# Неизвестный класс: person
# Неизвестный класс: bicycle
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: motorcycle
# Созданы аннотации для sm_00888.jpg в dataset_fire_smoke\yolo\data\train\labels\sm_00888.txt
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: motorcycle
# Неизвестный класс: motorcycle
# Неизвестный класс: person
# Неизвестный класс: bicycle
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: motorcycle
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Созданы аннотации для sm_00929.jpg в dataset_fire_smoke\yolo\data\train\labels\sm_00929.txt
# Неизвестный класс: person
# Неизвестный класс: person
# Созданы аннотации для sm_00943.jpg в dataset_fire_smoke\yolo\data\train\labels\sm_00943.txt
# Созданы аннотации для sm_00947.jpg в dataset_fire_smoke\yolo\data\train\labels\sm_00947.txt
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Созданы аннотации для sm_00952.jpg в dataset_fire_smoke\yolo\data\train\labels\sm_00952.txt
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Созданы аннотации для sm_00954.jpg в dataset_fire_smoke\yolo\data\train\labels\sm_00954.txt
# Созданы аннотации для sm_00956.jpg в dataset_fire_smoke\yolo\data\train\labels\sm_00956.txt
# Неизвестный класс: person
# Неизвестный класс: person
# Созданы аннотации для sm_00959.jpg в dataset_fire_smoke\yolo\data\train\labels\sm_00959.txt
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Созданы аннотации для sm_00984.jpg в dataset_fire_smoke\yolo\data\train\labels\sm_00984.txt
# Созданы аннотации для sm_00996.jpg в dataset_fire_smoke\yolo\data\train\labels\sm_00996.txt
# Созданы аннотации для sm_01001.jpg в dataset_fire_smoke\yolo\data\train\labels\sm_01001.txt
# Неизвестный класс: motorcycle
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: motorcycle
# Неизвестный класс: motorcycle
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: motorcycle
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Созданы аннотации для sm_01007.jpg в dataset_fire_smoke\yolo\data\train\labels\sm_01007.txt
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: motorcycle
# Неизвестный класс: motorcycle
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Созданы аннотации для sm_01008.jpg в dataset_fire_smoke\yolo\data\train\labels\sm_01008.txt
# Неизвестный класс: motorcycle
# Неизвестный класс: motorcycle
# Неизвестный класс: motorcycle
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: motorcycle
# Неизвестный класс: motorcycle
# Неизвестный класс: person
# Неизвестный класс: motorcycle
# Неизвестный класс: bicycle
# Неизвестный класс: motorcycle
# Неизвестный класс: person
# Неизвестный класс: motorcycle
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: motorcycle
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: motorcycle
# Неизвестный класс: person
# Созданы аннотации для sm_01011.jpg в dataset_fire_smoke\yolo\data\train\labels\sm_01011.txt
# Созданы аннотации для sm_01031.jpg в dataset_fire_smoke\yolo\data\train\labels\sm_01031.txt
# Неизвестный класс: person
# Созданы аннотации для sm_01037.jpg в dataset_fire_smoke\yolo\data\train\labels\sm_01037.txt
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: motorcycle
# Неизвестный класс: person
# Созданы аннотации для sm_01058.jpg в dataset_fire_smoke\yolo\data\train\labels\sm_01058.txt
# Созданы аннотации для sm_01062.jpg в dataset_fire_smoke\yolo\data\train\labels\sm_01062.txt
# Созданы аннотации для sm_01064.jpg в dataset_fire_smoke\yolo\data\train\labels\sm_01064.txt
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Созданы аннотации для sm_01092.jpg в dataset_fire_smoke\yolo\data\train\labels\sm_01092.txt
# Созданы аннотации для sm_01094.jpg в dataset_fire_smoke\yolo\data\train\labels\sm_01094.txt
# Созданы аннотации для sm_01095.jpg в dataset_fire_smoke\yolo\data\train\labels\sm_01095.txt
# Созданы аннотации для sm_01117.jpg в dataset_fire_smoke\yolo\data\train\labels\sm_01117.txt
# Созданы аннотации для sm_01121.jpg в dataset_fire_smoke\yolo\data\train\labels\sm_01121.txt
# Созданы аннотации для sm_01132.jpg в dataset_fire_smoke\yolo\data\train\labels\sm_01132.txt
# Неизвестный класс: person
# Созданы аннотации для sm_01162.jpg в dataset_fire_smoke\yolo\data\train\labels\sm_01162.txt
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Созданы аннотации для sm_01166.jpg в dataset_fire_smoke\yolo\data\train\labels\sm_01166.txt
# Неизвестный класс: person
# Неизвестный класс: person
# Созданы аннотации для sm_01168.jpg в dataset_fire_smoke\yolo\data\train\labels\sm_01168.txt
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: person
# Созданы аннотации для sm_01204.jpg в dataset_fire_smoke\yolo\data\train\labels\sm_01204.txt
# Созданы аннотации для sm_01205.jpg в dataset_fire_smoke\yolo\data\train\labels\sm_01205.txt
# Неизвестный класс: person
# Созданы аннотации для sm_01224.jpg в dataset_fire_smoke\yolo\data\train\labels\sm_01224.txt
# Созданы аннотации для sm_01259.jpg в dataset_fire_smoke\yolo\data\train\labels\sm_01259.txt
# Созданы аннотации для sm_01267.jpg в dataset_fire_smoke\yolo\data\train\labels\sm_01267.txt
# Неизвестный класс: person
# Неизвестный класс: motorcycle
# Неизвестный класс: person
# Созданы аннотации для u=1332554117,3167631526&fm=26&gp=0.jpg в dataset_fire_smoke\yolo\data\train\labels\u=1332554117,3167631526&fm=26&gp=0.txt
# Неизвестный класс: person
# Неизвестный класс: person
# Неизвестный класс: motorcycle
# Неизвестный класс: motorcycle
# Неизвестный класс: motorcycle
# Созданы аннотации для u=3186025966,1619569176&fm=26&gp=0.jpg в dataset_fire_smoke\yolo\data\train\labels\u=3186025966,1619569176&fm=26&gp=0.txt
# Неизвестный класс: motorcycle
# Созданы аннотации для u=3649283368,2577373232&fm=26&gp=0.jpg в dataset_fire_smoke\yolo\data\train\labels\u=3649283368,2577373232&fm=26&gp=0.txt
# Созданы аннотации для u=4079784958,3066531490&fm=26&gp=0.jpg в dataset_fire_smoke\yolo\data\train\labels\u=4079784958,3066531490&fm=26&gp=0.txt
# Неизвестный класс: motorcycle
# Неизвестный класс: motorcycle
# Созданы аннотации для u=4266402229,1307989802&fm=26&gp=0.jpg в dataset_fire_smoke\yolo\data\train\labels\u=4266402229,1307989802&fm=26&gp=0.txt
# Неизвестный класс: person
# Неизвестный класс: motorcycle
# Неизвестный класс: motorcycle
# Неизвестный класс: motorcycle
# Созданы аннотации для u=581614180,1792491636&fm=26&gp=0.jpg в dataset_fire_smoke\yolo\data\train\labels\u=581614180,1792491636&fm=26&gp=0.txt
# Неизвестный класс: bicycle
# Созданы аннотации для u=728658336,3440009586&fm=26&gp=0.jpg в dataset_fire_smoke\yolo\data\train\labels\u=728658336,3440009586&fm=26&gp=0.txt
# Создан файл dataset_fire_smoke\yolo\data.yaml
# Преобразование завершено!
